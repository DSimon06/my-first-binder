# %% [markdown]
# # Somme de deux sinusoïdes

# %% [markdown]
# On veut simuler la somme de deux sinusoïdes en fonction du décalage temporel $\Delta$t entre les deux.
# **1<sup>ère</sup> sinusoïde :** y<sub>1</sub>(t) = Y<sub>max</sub> * sin ( 2* pi * t / T )
# **2<sup>ème</sup> sinusoïde :** y<sub>2</sub>(t) = Y<sub>max</sub> * sin ( 2 * pi * (t + **$\Delta$t**) / T )
#
# ### 1ère partie : Décalage temporel $\Delta$t
#
# >**Q1-** Compléter le programme suivant avec les valeurs de l'amplitude Y<sub>max</sub> = 2 cm, de la période T = 10 s et un décalage temporel $\Delta$t de 0,1 fois la période T  puis exécuter le programme pour tracer les deux sinusoïdes y<sub>1</sub>(t) et y<sub>2</sub>(t).
#
# >**Q2-** Modifier la valeur du décalage temporel $\Delta$t, de `0.1*T` en `0.1*T`, sur une plage de valeurs de `-1*T` à `2*T`. Exécuter à chaque fois le programme et observer l'influence sur les courbes de y<sub>1</sub>(t) et y<sub>2</sub>(t).
#
# >*Répondre à la question 4 sur la feuille du TP.*

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# Choix des constantes
Ymax =                                # Amplitude en cm
T =                                   # Période en s
Deltat =                              # Décalage temporel

# Calcul des fonctions
t=np.linspace(0,20,100)               # 100 valeurs entre 0 et 1 seconde
y1 = Ymax*np.sin(2*np.pi*(t/T)) 
y2 = Ymax*np.sin(2*np.pi*((t+Deltat)/T)) 
                                      # Somme de y1 et y2

# Construction du graphique
plt.clf()
plt.plot(t,y1, label="y1(t)")         # Tracé de la courbe y1
plt.plot(t,y2, label="y2(t)")         # Tracé de la courbe y2
                                      # Tracé de la courbe somme de y1 et y2
    
plt.ylim(-4.5,4.5)                    # Valeurs limites pour l'axe des ordonnées
plt.grid()                            # Affichage d'un quadrillage
plt.title("Somme de deux sinusoïdes") # Titre du graphique
plt.xlabel("t(s)")                    # Etiquette de l'axe des abscisses
plt.ylabel("y(cm)")                   # Etiquette de l'axe des ordonnées
plt.legend()                          # Affichage de la légende
plt.show()                            # Affichage du graphique

# %% [markdown]
# ### 2ème Partie : Somme des sinusoïdes
#
# >**Q3-** Compléter le programme pour **calculer** et **tracer** sur le même graphique la somme des deux sinusoïdes : s(t) = y<sub>1</sub>(t) + y<sub>2</sub>(t).
#
# >**Q4-** A nouveau, modifier $\Delta$t pour tester les différents cas de figure et exécuter à chaque fois le programme pour observer l'influence du décalage temporel sur la somme des deux sinusoïdes s(t).
#
# ### 3ème Partie : Importance de l'amplitude
#
# >**Q5-** Programmer une amplitude différente pour les deux sinusoïdes : Y<sub>max,1</sub> = 2 cm et Y<sub>max,2</sub> = 1,5 cm
#
# >**Q6-** Choisir une valeur de $\Delta$t correspondant à une opposition de phase des deux sinusoïdes et exécuter le programme.
