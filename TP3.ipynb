# %% [markdown]
# # TP3 - Un lance-balle automatique

# %% [markdown]
# ### *_Exercice 28 p.312_*
# ____
# > Question 1 du livre
#
# *Indication : utiliser la conservation de l'énergie mécanique.*
# ____
# > Questions 2 et 3 à lire, mais à résoudre en exercice à la maison.
#
# *Indications :*
# - *Pour la question 2, établir les équations horaires du mouvement, puis éliminer le paramètre 't'.*
# - *Pour la question 3, déterminer ymax, connaissant vy au sommet de la trajectoire.**
# ____
# #### Tracé des deux courbes :

# %%
# Appel des biliothèques nécessaires pour le programme
from matplotlib import pyplot as plt
import math
import numpy as np

# Entrée des données de l'énoncé
v = 10
alpha = 30
g = 9.81
dt = 0.05
N = 100
H = 1.35

alpha_rad = alpha * math.pi / 180

# Création des grandeurs (vides) t, x, y1 et y2
t=[]
x=[]
y1=[]
y2=[]

# Calcul des différentes valeurs de ces grandeurs au cours du mouvement
for i in range (0,N):
    t.append(i*dt)
    x.append(v*np.cos(alpha_rad)*t[i])
    y1.append(-0.5*g*t[i]*t[i]+v*np.sin(alpha_rad)*t[i])
    y2.append(H)

# Tracé des deux courbes
plt.plot(x,y1,'b+')
plt.plot(x, y2,'r-')
plt.xlim(0,9)
plt.ylim(0,1.5)
plt.xlabel("x(m)")
plt.ylabel("y(m)")

plt.show()

# %% [markdown]
# >Q4- Que représentent les courbes y1 et y2 ? Conclure en répondant à la question 3.
#
# >Q5- A quoi sert la ligne « alpha_rad = alpha * math.pi / 180 » ?
#
# >Q6- Ajouter les lignes suivantes dans le programme afin de calculer et afficher la valeur maximale de y2, appelée flèche de la trajectoire :
# >>fleche=max(y1)
# >>print("La flèche de la trajectoire est",round(fleche,2), "m")
#
# >Q7- *(à la maison si manque de temps)* A l’aide de la conservation de l’énergie mécanique, calculer la vitesse de la balle au sommet de la trajectoire.
#
# Garance augmente de 5° l'angle de tir du lance balle pour augmenter la difficulté.
#
# >Q8- Modifier le programme et adapter les dimensions du graphique pour afficher correctement la courbe.
#
# >Q9- Phalco peut-il toujours attraper la balle quelle que soit sa position ?
#
# >QBonus- A l'aide du programme, déterminer l'influence de l'angle de tir sur la portée (point au sol atteint par la balle) et la flèche.
